# %% [markdown]
# # Data Understanding

# %%
#importing neccesery libraries
import pandas as pd
import numpy as np

# %%
#reading and displaying the dataset
online_course = pd.read_csv('online_course.csv')
online_course.head()
# Out:
#    UserID CourseCategory  TimeSpentOnCourse  NumberOfVideosWatched  \
# 0    5618         Health          29.979719                     17
# 1    4326           Arts          27.802640                      1
# 2    5849           Arts          86.820485                     14
# 3    4992        Science          35.038427                     17
# 4    3866    Programming          92.490647                     16
#
#    NumberOfQuizzesTaken  QuizScores  CompletionRate  DeviceType  \
# 0                     3   50.365656       20.860773           1
# 1                     5   62.615970       65.632415           1
# 2                     2   78.458962       63.812007           1
# 3                    10   59.198853       95.433162           0
# 4                     0   98.428285       18.102478           0
#
#    CourseCompletion
# 0                 0
# 1                 0
# 2                 1
# 3                 1
# 4                 0

# %%
#checking on the type of dataset
type(online_course)
# Out:
# pandas.core.frame.DataFrame

# %%
#checking the number of rows and columns
online_course.shape
# Out:
# (9000, 9)

# %%
#checking the data types
online_course.dtypes
# Out:
# UserID                     int64
# CourseCategory            object
# TimeSpentOnCourse        float64
# NumberOfVideosWatched      int64
# NumberOfQuizzesTaken       int64
# QuizScores               float64
# CompletionRate           float64
# DeviceType                 int64
# CourseCompletion           int64
# dtype: object

# %%
#checking if there any missing values presented in the dataset
online_course.isna().sum()
# Out:
# UserID                   0
# CourseCategory           0
# TimeSpentOnCourse        0
# NumberOfVideosWatched    0
# NumberOfQuizzesTaken     0
# QuizScores               0
# CompletionRate           0
# DeviceType               0
# CourseCompletion         0
# dtype: int64

# %% [markdown]
# - No missing values were found in this dataset.

# %%
#checking for the unique values in each columns
uniqueValues = online_course.nunique()
uniqueValues
# Out:
# UserID                   8123
# CourseCategory              5
# TimeSpentOnCourse        8123
# NumberOfVideosWatched      21
# NumberOfQuizzesTaken       11
# QuizScores               8123
# CompletionRate           8123
# DeviceType                  2
# CourseCompletion            2
# dtype: int64

# %%
#finding if there are any duplicate rows in the dataset
duplicate = online_course.duplicated(subset = ['UserID', 'CourseCategory', 'TimeSpentOnCourse', 'NumberOfVideosWatched', 
                                      'NumberOfQuizzesTaken', 'QuizScores', 'CompletionRate', 'DeviceType', 
                                      'CourseCompletion'])
duplicated_rows = online_course[duplicate]
duplicated_rows
# Out:
#       UserID CourseCategory  TimeSpentOnCourse  NumberOfVideosWatched  \
# 351     7812    Programming          76.319366                      0
# 383       17        Science          60.902054                      4
# 444     4293         Health           4.179856                     15
# 456     8734        Science          93.461459                      6
# 503     5995       Business          19.671294                      2
# ...      ...            ...                ...                    ...
# 8978    6019           Arts          37.018679                      9
# 8980    4184        Science          11.943595                      8
# 8982    6474         Health          72.200459                      5
# 8986    5835           Arts          96.596947                      0
# 8990     563         Health          63.751132                      0
#
#       NumberOfQuizzesTaken  QuizScores  CompletionRate  DeviceType  \
# ...

# %% [markdown]
# - 877 duplicate records were found in this dataset.

# %%
#dropping the duplicate records
online_course = online_course.drop_duplicates()
online_course
# Out:
#       UserID CourseCategory  TimeSpentOnCourse  NumberOfVideosWatched  \
# 0       5618         Health          29.979719                     17
# 1       4326           Arts          27.802640                      1
# 2       5849           Arts          86.820485                     14
# 3       4992        Science          35.038427                     17
# 4       3866    Programming          92.490647                     16
# ...      ...            ...                ...                    ...
# 8995    8757         Health          37.445225                     14
# 8996     894        Science          48.631443                      7
# 8997    6323         Health          38.212512                      3
# 8998    3652         Health          70.048665                     13
# 8999    5595         Health          93.589781                      7
#
#       NumberOfQuizzesTaken  QuizScores  CompletionRate  DeviceType  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
plt.figure(figsize=(6, 6))  
plt.hist(online_course['TimeSpentOnCourse'], bins=10, color='springgreen', edgecolor='black')
plt.title('Histogram of Time Spent by User on Course in Hours')  
plt.xlabel('TimeSpentOnCourse')  
plt.ylabel('Frequency')   
plt.show()

# %%
colors = ['limegreen','greenyellow', 'springgreen', 'aquamarine', 'darkgreen']
gender = online_course['CourseCategory'].value_counts()
gender.plot(kind = 'pie', figsize = (5,5), colors=colors, autopct='%1.1f%%')
plt.title('Plot of Course Category')
# Out:
# Text(0.5, 1.0, 'Plot of Course Category')

# %%
plt.figure(figsize=(6, 6))  
plt.hist(online_course['QuizScores'], bins=10, color='springgreen', edgecolor='black')
plt.title('Histogram of Average Quiz Scores in Percentage')  
plt.xlabel('QuizScores')  
plt.ylabel('Frequency')   
plt.show()

# %%
plt.figure(figsize=(6, 6))  
plt.hist(online_course['CompletionRate'], bins=10, color='springgreen', edgecolor='black')
plt.title('Histogram of Course Completion Rate in Percentage')  
plt.xlabel('CompletionRate')  
plt.ylabel('Frequency')   
plt.show()

# %%
videos_watched = online_course['NumberOfVideosWatched'].value_counts().sort_index()
videos_watched.plot(kind = 'bar', color= ['aquamarine'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Number of Videos Watched by Users')
# Out:
# Text(0.5, 1.0, 'Plot of Number of Videos Watched by Users')

# %%
quiz_taken = online_course['NumberOfQuizzesTaken'].value_counts().sort_index()
quiz_taken.plot(kind = 'bar', color= ['aquamarine'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Number of Quizzes Taken')
# Out:
# Text(0.5, 1.0, 'Plot of Number of Quizzes Taken')

# %%
colors = ['limegreen','darkgreen']
device_type = online_course['DeviceType'].value_counts()
device_type.plot(kind = 'pie', figsize = (5,5), colors=colors, autopct='%1.1f%%')
plt.title('Plot of Device Type')
# Out:
# Text(0.5, 1.0, 'Plot of Device Type')

# %%
colors = ['limegreen','darkgreen']
course_completion = online_course['CourseCompletion'].value_counts()
course_completion.plot(kind = 'pie', figsize = (5,5), colors=colors, autopct='%1.1f%%')
plt.title('Plot of Course Completion Status')
# Out:
# Text(0.5, 1.0, 'Plot of Course Completion Status')

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
columns = ['CourseCategory']
label_encoder = LabelEncoder()
for col in columns:
    online_course[col + '_encoded'] = label_encoder.fit_transform(online_course[col])
online_course = online_course.drop(columns=columns)

# %%
online_course.head()
# Out:
#    UserID  TimeSpentOnCourse  NumberOfVideosWatched  NumberOfQuizzesTaken  \
# 0    5618          29.979719                     17                     3
# 1    4326          27.802640                      1                     5
# 2    5849          86.820485                     14                     2
# 3    4992          35.038427                     17                    10
# 4    3866          92.490647                     16                     0
#
#    QuizScores  CompletionRate  DeviceType  CourseCompletion  \
# 0   50.365656       20.860773           1                 0
# 1   62.615970       65.632415           1                 0
# 2   78.458962       63.812007           1                 1
# 3   59.198853       95.433162           0                 1
# 4   98.428285       18.102478           0                 0
#
#    CourseCategory_encoded
# 0                       2
# 1                       0
# 2                       0
# 3                       4
# ...

# %% [markdown]
# # Modelling

# %%
X = online_course.drop(['UserID', 'CourseCompletion'], axis=1)
Y = online_course['CourseCompletion']

# %%
#To balance the imbalanced class
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=123)
Xtrain_balanced, Ytrain_balanced = smote.fit_resample(X, Y)
print("Balanced Xtrain shape:", Xtrain_balanced.shape)
print("Balanced Ytrain shape:", Ytrain_balanced.shape)
# Out:
# Balanced Xtrain shape: (9110, 7)
# Balanced Ytrain shape: (9110,)

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(Xtrain_balanced, Ytrain_balanced, random_state=123, test_size=0.2)

# %%
Xtrain.shape
# Out:
# (7288, 7)

# %%
Xtest.shape
# Out:
# (1822, 7)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
Xtrain = scaler.fit_transform(Xtrain)
Xtrain
# Out:
# array([[-1.1322776 ,  1.30829089,  0.8966636 , ..., -0.62941294,
#          1.04520287, -0.69476448],
#        [ 0.04773154,  0.28723137, -1.7027335 , ..., -0.54956119,
#         -0.95675206, -1.41564197],
#        [ 0.73237004, -1.75488768,  0.24681432, ...,  1.46719882,
#         -0.95675206,  0.02611302],
#        ...,
#        [-0.12320064, -0.2232984 , -1.7027335 , ..., -0.43510283,
#         -0.95675206, -1.41564197],
#        [ 1.51608749,  0.45740795, -1.37780886, ...,  0.71956857,
#         -0.95675206,  0.02611302],
#        [ 1.36538676, -0.73382816,  1.22158823, ...,  1.38833832,
#          1.04520287,  0.02611302]])

# %%
Xtest = scaler.transform(Xtest)
Xtest
# Out:
# array([[ 0.34608269, -0.73382816, -0.40303495, ..., -0.71233335,
#         -0.95675206, -1.41564197],
#        [ 0.5930269 ,  0.96793772, -0.40303495, ..., -1.24346405,
#         -0.95675206, -0.69476448],
#        [ 0.34182002, -0.73382816,  1.54651287, ...,  1.48501703,
#          1.04520287, -1.41564197],
#        ...,
#        [ 1.01331817, -0.56365157, -0.72795959, ...,  1.18386079,
#         -0.95675206, -0.69476448],
#        [-1.07683474,  1.47846748, -1.37780886, ..., -1.24863398,
#          1.04520287,  1.467868  ],
#        [-1.64904169,  0.79776113,  1.54651287, ..., -1.59751121,
#          1.04520287,  0.02611302]])

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB 
model_NB = GaussianNB()                       
model_NB.fit(Xtrain, Ytrain)                  
NB_model = model_NB.predict(Xtest)

# %%
from sklearn.metrics import accuracy_score
acc_NB = accuracy_score(Ytest, NB_model)
acc_NB
# Out:
# 0.8369923161361141

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, NB_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.83       915
#            1       0.82      0.86      0.84       907
#
#     accuracy                           0.84      1822
#    macro avg       0.84      0.84      0.84      1822
# weighted avg       0.84      0.84      0.84      1822

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_NB = confusion_matrix(Ytest, NB_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_NB, display_labels = model_NB.classes_)
disp.plot()

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier 
model_RF = RandomForestClassifier()                       
model_RF.fit(Xtrain, Ytrain)                  
RF_model = model_RF.predict(Xtest)

# %%
acc_RF = accuracy_score(Ytest, RF_model)
acc_RF
# Out:
# 0.9610318331503842

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, RF_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       915
#            1       0.98      0.94      0.96       907
#
#     accuracy                           0.96      1822
#    macro avg       0.96      0.96      0.96      1822
# weighted avg       0.96      0.96      0.96      1822

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_RF = confusion_matrix(Ytest, RF_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_RF, display_labels = model_RF.classes_)
disp.plot()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
model_LR = linear_model.LogisticRegression()
model_LR.fit(Xtrain, Ytrain)
LR_model = model_LR.predict(Xtest)

# %%
acc_LR = accuracy_score(Ytest, LR_model)
acc_LR
# Out:
# 0.7991218441273326

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, LR_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.80       915
#            1       0.79      0.82      0.80       907
#
#     accuracy                           0.80      1822
#    macro avg       0.80      0.80      0.80      1822
# weighted avg       0.80      0.80      0.80      1822

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_LR = confusion_matrix(Ytest, LR_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_LR, display_labels = model_LR.classes_)
disp.plot()

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model_DT = DecisionTreeClassifier()
model_DT.fit(Xtrain, Ytrain)
DT_model = model_DT.predict(Xtest)

# %%
acc_DT = accuracy_score(Ytest, DT_model)
acc_DT
# Out:
# 0.9039517014270033

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, DT_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90       915
#            1       0.90      0.90      0.90       907
#
#     accuracy                           0.90      1822
#    macro avg       0.90      0.90      0.90      1822
# weighted avg       0.90      0.90      0.90      1822

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_DT = confusion_matrix(Ytest, DT_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_DT, display_labels = model_DT.classes_)
disp.plot()

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn.svm import SVC
model_SVM = SVC()
model_SVM.fit(Xtrain, Ytrain)
SVM_model = model_SVM.predict(Xtest)

# %%
acc_SVM = accuracy_score(Ytest, SVM_model)
acc_SVM
# Out:
# 0.8880351262349067

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, SVM_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89       915
#            1       0.89      0.88      0.89       907
#
#     accuracy                           0.89      1822
#    macro avg       0.89      0.89      0.89      1822
# weighted avg       0.89      0.89      0.89      1822

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_SVM = confusion_matrix(Ytest, SVM_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_SVM, display_labels = model_DT.classes_)
disp.plot()

# %% [markdown]
# ### K-Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier
error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(Xtrain,Ytrain)
 pred_i = knn.predict(Xtest)
 error_rate.append(np.mean(pred_i != Ytest))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='darkgreen', linestyle='dashed', marker='o', markerfacecolor='aquamarine', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
acc = []
from sklearn import metrics
for i in range(1,40):
    neigh = KNeighborsClassifier(n_neighbors = i).fit(Xtrain,Ytrain)
    yhat = neigh.predict(Xtest)
    acc.append(metrics.accuracy_score(Ytest, yhat))
    
plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color = 'darkgreen',linestyle='dashed', marker='o',markerfacecolor='aquamarine', markersize=10)
plt.title('Accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
max_accuracy = max(acc)
optimal_k_value = acc.index(max_accuracy) + 1
print("Maximum accuracy:",max_accuracy,"at K =", optimal_k_value)
# Out:
# Maximum accuracy: 0.8918770581778266 at K = 16

# %% [markdown]
# - The optimal k-value is 16 based on the above charts.

# %%
knn = KNeighborsClassifier(n_neighbors=16)
model_KNN = knn.fit(Xtrain, Ytrain)
KNN_model = knn.predict(Xtest)

# %%
acc_KNN = accuracy_score(Ytest, KNN_model)
acc_KNN
# Out:
# 0.8918770581778266

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, KNN_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       915
#            1       0.89      0.89      0.89       907
#
#     accuracy                           0.89      1822
#    macro avg       0.89      0.89      0.89      1822
# weighted avg       0.89      0.89      0.89      1822

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_KNN = confusion_matrix(Ytest, KNN_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_KNN, display_labels = model_KNN.classes_)
disp.plot()

# %% [markdown]
# # Evaluation

# %%
plt.rcParams["figure.figsize"] = [7,7]
acc = [acc_NB, acc_RF, acc_LR, acc_DT, acc_SVM, acc_KNN]
models = ['NB', 'RF', 'LR', 'DT', 'SVM','KNN']

plt.plot(models,acc, color = 'darkgreen', marker = 'o', markerfacecolor = 'aquamarine')
plt.grid(False)
plt.show()

# %% [markdown]
# - Random Forest (RF) performs best according to the evaluation conducted.
